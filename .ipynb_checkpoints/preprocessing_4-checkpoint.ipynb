# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                                   Title  \
# 0     JANUARY          3                              The Grudge
# 1     JANUARY         10                              Underwater
# 2     JANUARY         10                             Like a Boss
# 3     JANUARY         10                           Three Christs
# 4     JANUARY         10                       Inherit the Viper
# 5     JANUARY         10                              The Sonata
# 6     JANUARY         10      The Murder of Nicole Brown Simpson
# 7     JANUARY         17                       Bad Boys for Life
# 8     JANUARY         17                                Dolittle
# 9     JANUARY         17                       A Fall from Grace
# 10    JANUARY         24                           The Gentlemen
# 11    JANUARY         24                             The Turning
# 12    JANUARY         24                   The Last Full Measure
# 13    JANUARY         24                         The Night House
# 14    JANUARY         24                              John Henry
# 15    JANUARY         31                      The Rhythm Section
# 16    JANUARY         31                         Gretel & Hansel
# 17    JANUARY         31                           The Assistant
# 18   FEBRUARY          7                           Birds of Prey
# 19   FEBRUARY          7                               The Lodge
# 20   FEBRUARY          7       Timmy Failure: Mistakes Were Made
# 21   FEBRUARY          7                              Horse Girl
# 22   FEBRUARY         12  To All the Boys: P.S. I Still Love You
# 23   FEBRUARY         14                      Sonic the Hedgehog
# 24   FEBRUARY         14                          Fantasy Island
# 25   FEBRUARY         14                          The Photograph
# 26   FEBRUARY         14                                Downhill
# 27   FEBRUARY         14                        Spy Intervention
# 28   FEBRUARY         14               The Kindness of Strangers
# 29   FEBRUARY         21                    The Call of the Wild
# ..        ...        ...                                     ...
# 240  DECEMBER          4                                The Prom
# 241  DECEMBER          4                             All My Life
# 242  DECEMBER          4                             Godmothered
# 243  DECEMBER          4                           Half Brothers
# 244  DECEMBER          4                                  Wander
# 245  DECEMBER          4                              Black Bear
# 246  DECEMBER         10                       Let Them All Talk
# 247  DECEMBER         11                        The Midnight Sky
# 248  DECEMBER         11                                Songbird
# 249  DECEMBER         11                     Wild Mountain Thyme
# 250  DECEMBER         11                                  Safety
# 251  DECEMBER         11                           Wander Darkly
# 252  DECEMBER         11                          I'm Your Woman
# 253  DECEMBER         11                            The Stand In
# 254  DECEMBER         11                               Archenemy
# 255  DECEMBER         11                           Farewell Amor
# 256  DECEMBER         18                          Monster Hunter
# 257  DECEMBER         18                               Greenland
# 258  DECEMBER         18                                  Fatale
# 259  DECEMBER         18                                Skylines
# 260  DECEMBER         18                           Hunter Hunter
2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->tmdbv3api) (3.0.4)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '674c65f3d936f6565c20f1ee8eccf309'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2020
# Out:
#                                       Title  \
# 0                                The Grudge
# 1                                Underwater
# 2                               Like a Boss
# 3                             Three Christs
# 4                         Inherit the Viper
# 5                                The Sonata
# 6        The Murder of Nicole Brown Simpson
# 7                         Bad Boys for Life
# 8                                  Dolittle
# 9                         A Fall from Grace
# 10                            The Gentlemen
# 11                              The Turning
# 12                    The Last Full Measure
# 13                          The Night House
# 14                               John Henry
# 15                       The Rhythm Section
# 16                          Gretel & Hansel
# 17                            The Assistant
# 18                            Birds of Prey
# 19                                The Lodge
# 20        Timmy Failure: Mistakes Were Made
# 21                               Horse Girl
# 22   To All the Boys: P.S. I Still Love You
# 23                       Sonic the Hedgehog
# 24                           Fantasy Island
# 25                           The Photograph
# 26                                 Downhill
# 27                         Spy Intervention
# 28                The Kindness of Strangers
# 29                     The Call of the Wild
# ..                                      ...
# 240                                The Prom
# 241                             All My Life
# 242                             Godmothered
# 243                           Half Brothers
# 244                                  Wander
# 245                              Black Bear
# 246                       Let Them All Talk
# 247                        The Midnight Sky
# 248                                Songbird
# 249                     Wild Mountain Thyme
# 250                                  Safety
# 251                           Wander Darkly
# 252                          I'm Your Woman
# 253                            The Stand In
# 254                               Archenemy
# 255                           Farewell Amor
# 256                          Monster Hunter
# 257                               Greenland
# 258                                  Fatale
# 259                                Skylines
# 260                           Hunter Hunter
# 261    Ariana Grande: Excuse Me, I Love You
# 262                           Sylvie's Love
# 263                       Wonder Woman 1984
# 264                                    Soul
# 265                        We Can Be Heroes
# 266                       News of the World
# 267                      One Night in Miami
# 268                   Promising Young Woman
# 269                       Pieces of a Woman
#
#                                          Cast and crew
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# 5    Andrew Desmond (director/screenplay); Arthur M...
# 6    Daniel Farrands (director); Michael Arter (scr...
# 7    Adil El Arbi and Bilall Fallah (directors); Ch...
# 8    Stephen Gaghan (director/screenplay); Dan Greg...
# 9    Tyler Perry (director/screenplay); Crystal R. ...
# 10   Guy Ritchie (director/screenplay); Matthew McC...
# 11   Floria Sigismondi (director); Carey Hayes, Cha...
# 12   Todd Robinson (director/screenplay); Sebastian...
# 13   David Bruckner (director); Ben Collins, Luke P...
# 14   Will Forbes (director); Doug Skinner, Will For...
# 15   Reed Morano (director); Mark Burnell (screenpl...
# 16   Oz Perkins (director/screenplay); Rob Hayes (s...
# 17   Kitty Green (director/screenplay); Julia Garne...
# 18   Cathy Yan (director); Christina Hodson (screen...
# 19   Veronika Franz, Severin Fiala (directors/scree...
# 20   Tom McCarthy (director/screenplay); Stephan Pa...
# 21   Jeff Baena (director/screenplay); Alison Brie ...
# 22   Michael Fimognari (director); Sofia Alvarez, J...
# 23   Jeff Fowler (director); Patrick Casey, Josh Mi...
# 24   Jeff Wadlow (director/screenplay); Chris Roach...
# 25   Stella Meghie (director/screenplay); Issa Rae,...
# 26   Nat Faxon, Jim Rash (directors); Jesse Armstro...
# 27   Drew Mylrea (director); Mark Famiglietti, Lane...
# 28   Lone Scherfig (director/screenplay); Andrea Ri...
# 29   Chris Sanders (director); Michael Green (scree...
# ..                                                 ...
# 240  Ryan Murphy (director); Chad Beguelin, Bob Mar...
# 241  Marc Meyers (director); Todd Rosenberg (screen...
# 242  Sharon Maguire (director); Kari Granlund, Meli...
# 243  Luke Greenfield (director); Eduardo Cisneros, ...
# 244  April Mullen (director); Tim Doiron (screenpla...
# 245  Lawrence Michael Levine (director/screenplay);...
# 246  Steven Soderbergh (director); Deborah Eisenber...
# 247  George Clooney (director); Mark L. Smith (scre...
# 248  Adam Mason (director/screenplay); Simon Boyes ...
# 249  John Patrick Shanley (director/screenplay); Em...
# 250  Reginald Hudlin (director); Nick Santora (scre...
# 251  Tara Miele (director/screenplay); Sienna Mille...
# 252  Julia Hart (director/screenplay); Jordan Horow...
# 253  Jamie Babbit (director); Sam Bain (screenplay)...
# 254  Adam Egypt Mortimer (director/screenplay); Joe...
# 255  Ekwa Msangi (director/screenplay); Ntare Mwine...
# 256  Paul W. S. Anderson (director/screenplay); Mil...
# 257  Ric Roman Waugh (director); Chris Sparling (sc...
# 258  Deon Taylor (director); David Loughery (screen...
# 259  Liam O'Donnell (director/screenplay); Lindsey ...
# 260  Shawn Linden (director/screenplay); Devon Sawa...
# 261             Paul Dugdale (director); Ariana Grande
# 262  Eugene Ashe (director/screenplay); Tessa Thomp...
# 263  Patty Jenkins (director/screenplay); Geoff Joh...
# 264  Pete Docter (director/screenplay); Mike Jones,...
# 265  Robert Rodriguez (director/screenplay); Priyan...
# 266  Paul Greengrass (director/screenplay); Luke Da...
# 267  Regina King (director); Kemp Powers (screenpla...
# 268  Emerald Fennell (director/screenplay); Carey M...
# 269  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [270 rows x 2 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title  ...         actor_3_name
# 0               The Grudge  ...             John Cho
# 1               Underwater  ...      Jessica Henwick
# 2            Three Christs  ...       Walton Goggins
# 3              Like a Boss  ...          Salma Hayek
# 4        Inherit the Viper  ...       Chandler Riggs
# ..                     ...  ...                  ...
# 250      News of the World  ...                  NaN
# 251     One Night in Miami  ...          Aldis Hodge
# 252  Promising Young Woman  ...          Alison Brie
# 253          Sylvie's Love  ...  Ryan Michelle Bathe
# 254      Pieces of a Woman  ...         Molly Parker
#
# [255 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name  ...            movie_title
# 0       Nicolas Pesce  ...             The Grudge
# 1      William Eubank  ...             Underwater
# 2           Jon Avnet  ...          Three Christs
# 3       Miguel Arteta  ...            Like a Boss
# 4      Anthony Jerjen  ...      Inherit the Viper
# ..                ...  ...                    ...
# 250   Paul Greengrass  ...      News of the World
# 251       Regina King  ...     One Night in Miami
# 252   Emerald Fennell  ...  Promising Young Woman
# 253       Eugene Ashe  ...          Sylvie's Love
# 254  Kornél Mundruczó  ...      Pieces of a Woman
#
# [255 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      2
# actor_3_name     27
# genres            2
# movie_title       0
# comb             28
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#            director_name  ...                                               comb
# 0          Nicolas Pesce  ...  Andrea Riseborough Demián Bichir John Cho Nico...
# 1         William Eubank  ...  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              Jon Avnet  ...  Richard Gere Peter Dinklage Walton Goggins Jon...
# 3          Miguel Arteta  ...  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 4         Anthony Jerjen  ...  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                   ...  ...                                                ...
# 249  Paul W. S. Anderson  ...  Milla Jovovich Tony Jaa Tip "T.I." Harris Paul...
# 251          Regina King  ...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 252      Emerald Fennell  ...  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 253          Eugene Ashe  ...  Tessa Thompson Nnamdi Asomugha Ryan Michelle B...
# 254     Kornél Mundruczó  ...  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [227 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')

# %%
old_df
# Out:
#               director_name       actor_1_name          actor_2_name  \
# 0             James Cameron        CCH Pounder      Joel David Moore
# 1            Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                Sam Mendes    Christoph Waltz          Rory Kinnear
# 3         Christopher Nolan          Tom Hardy        Christian Bale
# 4               Doug Walker        Doug Walker            Rob Walker
# ...                     ...                ...                   ...
# 5864           Greta Gerwig      Saoirse Ronan           Emma Watson
# 5865             Sam Mendes      George MacKay  Dean-Charles Chapman
# 5866  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5867        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 5868           Waymon Boone        Mena Suvari          Kevin Pollak
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5864         Florence Pugh                    Drama Romance
# 5865           Mark Strong         War Drama Action History
# 5866           Brie Larson                      Drama Crime
# 5867           Aldis Hodge                            Drama
# 5868               unknown                  Horror Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5864                                       little women
# 5865                                               1917
# 5866                                         just mercy
# 5867                                           clemency
# 5868                                         apparition
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5864  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5865  George MacKay Dean-Charles Chapman Mark Strong...
# 5866  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5867  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5868  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5869 rows x 7 columns]

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6005    Joseph Kosinski       Tom Cruise      Miles Teller
# 6006      Joel Crawford     Nicolas Cage        Emma Stone
# 6007        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6008       Ridley Scott       Matt Damon       Adam Driver
# 6009    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6005     Jennifer Connelly                     Action Drama
# 6006         Ryan Reynolds       Animation Adventure Family
# 6007         Marlon Wayans                      Music Drama
# 6008           Jodie Comer                            Drama
# 6009       Neil Sandilands                    Drama Western
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6005                                  top gun: maverick
# 6006                                       the croods 2
# 6007                                            respect
# 6008                                      the last duel
# 6009                                  news of the world
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6005  Tom Cruise Miles Teller Jennifer Connelly Jose...
# 6006  Nicolas Cage Emma Stone Ryan Reynolds Joel Cra...
# 6007  Jennifer Hudson Forest Whitaker Marlon Wayans ...
# 6008  Matt Damon Adam Driver Jodie Comer Ridley Scot...
# 6009  Tom Hanks Helena Zengel Neil Sandilands Paul G...
#
# [6010 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
